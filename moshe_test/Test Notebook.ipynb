# %% [markdown]
# To open notebook in Colab please click below:
#
# <a href="https://colab.research.google.com/github/bwolfson2/moshe_test/blob/main/moshe_test/Test%20Notebook.ipynb" target="_parent"> <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" /> </a>'

# %% [markdown]
# # IF OPENING IN COLAB, PLEASE REMEMBER TO SAVE THE NOTEBOOK TO YOUR GOOGLE DRIVE

# %% [markdown]
# # Please put code for each question in relevant cell below:

# %% [markdown]
# ## Q3

# %%
#CODE HERE
# dataset can be found at the following URL:
# https://github.com/bwolfson2/moshe_test/blob/main/moshe_test/Dataset%20-%20myFileName2.csv?raw=true

# %% [markdown]
# ## Q4

# %%
#CODE HERE

# %% [markdown]
# ## Q5

# %%
#CODE HERE

# %% [markdown]
# ## Q6

# %%
#CODE HERE

# %% [markdown]
# ## Q8

# %%
#CODE HERE

# %% [markdown]
# ## Q9

# %%
#CODE HERE
